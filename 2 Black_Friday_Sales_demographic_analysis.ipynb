# %% [markdown]
# # **2 Black_Friday_Sales_demographic_analysis.py**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load and clean the dataset
df = pd.read_csv("BlackFriday.csv")
df.columns = df.columns.str.strip()

# %%
# ----- Demographic-Based Purchase Analysis -----

# 1. Average Purchase by Gender
print("🧑‍🤝‍🧑 Average Purchase by Gender:")
print(df.groupby('Gender')['Purchase'].mean(), "\n")

# 2. Average Purchase by Age Group
print("🎂 Average Purchase by Age Group:")
print(df.groupby('Age')['Purchase'].mean(), "\n")

# 3. Average Purchase by City Category
print("🏙️ Average Purchase by City Category:")
print(df.groupby('City_Category')['Purchase'].mean(), "\n")

# 4. Average Purchase by Marital Status
print("💍 Average Purchase by Marital Status:")
print(df.groupby('Marital_Status')['Purchase'].mean(), "\n")
# Out:
# 🧑‍🤝‍🧑 Average Purchase by Gender:
# Gender
# F    8809.761349
# M    9504.771713
# Name: Purchase, dtype: float64
#
# 🎂 Average Purchase by Age Group:
# Age
# 0-17     9020.126878
# 18-25    9235.197575
# 26-35    9314.588970
# 36-45    9401.478758
# 46-50    9284.872277
# 51-55    9620.616620
# 55+      9453.898579
# Name: Purchase, dtype: float64
#
# 🏙️ Average Purchase by City Category:
# City_Category
# A    8958.011014
# B    9198.657848
# C    9844.441855
# Name: Purchase, dtype: float64
#
# 💍 Average Purchase by Marital Status:
# Marital_Status
# 0    9333.325467
# 1    9334.632681
# Name: Purchase, dtype: float64

# %%
sns.set(style="whitegrid")
y_range = (5000, 15000)
age_order = ['0-17', '18-25', '26-35', '36-45', '46-50', '51-55', '55+']

plots = [
    ("Gender", "pastel", None, "Average Purchase by Gender"),
    ("Age", "Set2", age_order, "Average Purchase by Age Group"),
    ("City_Category", "coolwarm", None, "Average Purchase by City Category"),
    ("Marital_Status", "muted", None, "Average Purchase by Marital Status")
]

for x, palette, order, title in plots:
    plt.figure(figsize=(6, 5))
    sns.barplot(x=x, y='Purchase', data=df, estimator='mean', ci=None, palette=palette, order=order)
    plt.title(title)
    plt.xlabel(x.replace('_', ' '))
    plt.ylabel("Average Purchase")
    plt.ylim(y_range)
    plt.tight_layout()
    plt.show()
# Out:
# /tmp/ipython-input-3095609904.py:14: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=x, y='Purchase', data=df, estimator='mean', ci=None, palette=palette, order=order)
# /tmp/ipython-input-3095609904.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x, y='Purchase', data=df, estimator='mean', ci=None, palette=palette, order=order)
# /tmp/ipython-input-3095609904.py:14: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=x, y='Purchase', data=df, estimator='mean', ci=None, palette=palette, order=order)
# /tmp/ipython-input-3095609904.py:14: FutureWarning:
#
# ...

# %% [markdown]
# # 4 **Black_Friday_Sales_data_visualization.py**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Distribution of purchase amounts
sns.histplot(df['Purchase'], kde=True)
plt.title('Purchase Amount Distribution')
plt.show()

# %%
# Average purchase by Gender
sns.barplot(x='Gender', y='Purchase', data=df)
plt.title('Average Purchase by Gender')
plt.show()

# %%
# Customer count by Age
sns.countplot(x='Age', data=df)
plt.title('Customer Count by Age Group')
plt.show()

# %%
# Histogram of product categories
sns.histplot(df['Product_Category_1'], bins=15)
plt.title('Product Category 1 Popularity')
plt.show()

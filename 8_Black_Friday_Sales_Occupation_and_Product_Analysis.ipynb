# %% [markdown]
# # 8  **Black_Friday_Sales_Occupation and Product Analysis**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv("BlackFriday.csv")

# %%
occupation_purchase = df.groupby('Occupation')['Purchase'].mean().sort_values(ascending=False)
print("\n🎯 Average Purchase by Occupation:")
print(occupation_purchase)
# Out:
# 🎯 Average Purchase by Occupation:
# Occupation
# 17    9906.378997
# 12    9883.052460
# 15    9866.239925
# 8     9576.508530
# 14    9568.536426
# 7     9502.175276
# 16    9457.133118
# 13    9424.449391
# 5     9388.848978
# 6     9336.378620
# 11    9299.467190
# 4     9279.026742
# 3     9238.077277
# 18    9233.671418
# 0     9186.946726
# 10    9052.836410
# 2     9025.938982
# 1     9017.703095
# 20    8881.099514
# 19    8754.249162
# 9     8714.335934
# Name: Purchase, dtype: float64

# %%
total_purchase = df.groupby('Occupation')['Purchase'].sum().sort_values(ascending=False)
print("\n💰 Total Purchase by Occupation:")
print(total_purchase)
# Out:
# 💰 Total Purchase by Occupation:
# Occupation
# 4     657530393
# 0     625814811
# 7     549282744
# 1     414552829
# 17    387240355
# 12    300672105
# 20    292276985
# 14    255594745
# 16    234442330
# 2     233275393
# 6     185065697
# 3     160428450
# 15    116540026
# 10    114273954
# 5     112525355
# 11    105437359
# 19     73115489
# 13     71135744
# 18     60249706
# 9      53619309
# 8      14594599
# Name: Purchase, dtype: int64

# %%
top_product_by_occupation = df.groupby('Occupation')['Product_Category_1'].agg(lambda x: x.mode()[0])
print("\n📦 Most Common Product_Category_1 by Occupation:")
print(top_product_by_occupation)
# Out:
# 📦 Most Common Product_Category_1 by Occupation:
# Occupation
# 0     5
# 1     5
# 2     5
# 3     5
# 4     5
# 5     1
# 6     5
# 7     1
# 8     1
# 9     5
# 10    5
# 11    5
# 12    1
# 13    8
# 14    5
# 15    1
# 16    5
# 17    1
# 18    1
# 19    5
# 20    5
# Name: Product_Category_1, dtype: int64

# %%
occupation_counts = df['Occupation'].value_counts().sort_values(ascending=False)

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x=occupation_purchase.index, y=occupation_purchase.values, palette='viridis')
plt.title("Average Purchase by Occupation")
plt.xlabel("Occupation Code")
plt.ylabel("Average Purchase Amount")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1990812298.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=occupation_purchase.index, y=occupation_purchase.values, palette='viridis')

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='Product_Category_1', hue='Occupation', data=df, palette='tab20', edgecolor='gray')
plt.title("Product Category 1 vs Occupation")
plt.xlabel("Product Category 1")
plt.ylabel("Count")
plt.legend(title="Occupation", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
